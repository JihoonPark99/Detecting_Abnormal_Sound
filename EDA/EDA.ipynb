# %% [markdown]
# # EDA

# %% [markdown]
# 1. fan, valve, slider, pump, fan 경로 파일 개수 세기
# 2. 동영상 길이 각각 파악

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import glob
import os

# %%
from EDA import *

# %% [markdown]
# ## 개수세기

# %% [markdown]
# fan, valve, slider, pump

# %%
path0 = '/data/time_series/fan/0'
path_6 = '/data/time_series/fan/_6'
path6 = '/data/time_series/fan/6'

# %%
Fan0 = EDA(path0)
Fan0.__init__(path0)
fan0 = Fan0.make_path_dic()
fan0.keys()
# Out:
# good
# good
#
#
# d_04
# normal : 1033
# abnormal : 348
#
#
# d_02
# normal : 1016
# abnormal : 359
#
#
# d_06
# normal : 1015
# abnormal : 361
#
#
# d_00
# normal : 1011
# abnormal : 407
# dict_keys(['d_04', 'd_02', 'd_06', 'd_00'])

# %%
fan0
# Out:
# {'d_04': {'normal': ['/data/time_series/fan/0/id_04/normal/00000226.wav',
#    '/data/time_series/fan/0/id_04/normal/00000291.wav',
#    '/data/time_series/fan/0/id_04/normal/00000646.wav',
#    '/data/time_series/fan/0/id_04/normal/00000283.wav',
#    '/data/time_series/fan/0/id_04/normal/00000487.wav',
#    '/data/time_series/fan/0/id_04/normal/00000766.wav',
#    '/data/time_series/fan/0/id_04/normal/00000940.wav',
#    '/data/time_series/fan/0/id_04/normal/00000309.wav',
#    '/data/time_series/fan/0/id_04/normal/00000253.wav',
#    '/data/time_series/fan/0/id_04/normal/00000795.wav',
#    '/data/time_series/fan/0/id_04/normal/00000324.wav',
#    '/data/time_series/fan/0/id_04/normal/00000718.wav',
#    '/data/time_series/fan/0/id_04/normal/00000619.wav',
#    '/data/time_series/fan/0/id_04/normal/00000966.wav',
#    '/data/time_series/fan/0/id_04/normal/00000280.wav',
#    '/data/time_series/fan/0/id_04/normal/00000127.wav',
# ...

# %%
Fan_6 = EDA(path_6)
Fan_6.__init__(path_6)
fan_6 = Fan_6.make_path_dic()
fan_6.keys()
# Out:
# good
# good
#
#
# d_04
# normal : 1033
# abnormal : 348
#
#
# d_02
# normal : 1016
# abnormal : 359
#
#
# d_06
# normal : 1015
# abnormal : 361
#
#
# d_00
# normal : 1011
# abnormal : 407
# dict_keys(['d_04', 'd_02', 'd_06', 'd_00'])

# %%
Fan6 = EDA(path6)
Fan6.__init__(path6)
fan6 = Fan6.make_path_dic()
fan6.keys()
# Out:
# good
# good
#
#
# d_04
# normal : 1033
# abnormal : 348
#
#
# d_02
# normal : 1016
# abnormal : 359
#
#
# d_06
# normal : 1015
# abnormal : 361
#
#
# d_00
# normal : 1011
# abnormal : 407
# dict_keys(['d_04', 'd_02', 'd_06', 'd_00'])

# %% [markdown]
# ### Object_cnt.csv
# - 모든 fan파일들에 대한 개수 데이터프레임

# %%
object_cnt = pd.read_csv('Object_cnt.csv')
object_cnt
# Out:
#    Object model  type  no_abnor  count
# 0     fan     0  d_00    normal   1011
# 1     fan     0  d_00  abnormal    407
# 2     fan     0  d_02    normal   1016
# 3     fan     0  d_02  abnormal    359
# 4     fan     0  d_04    normal   1033
# ..    ...   ...   ...       ...    ...
# 91   pump     6  d_02  abnormal    111
# 92   pump     6  d_04    normal    702
# 93   pump     6  d_04  abnormal    100
# 94   pump     6  d_06    normal   1036
# 95   pump     6  d_06  abnormal    102
#
# [96 rows x 5 columns]
